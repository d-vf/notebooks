# %% [markdown]
# <a href="https://colab.research.google.com/github/d-vf/notebooks/blob/master/IPR_VC_and_Public_Funds_Probit_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup
#
# * R kernel (https://github.com/IRkernel/IRkernel)

# %%
cat(system('python3 -c "from google.colab import drive\ndrive.mount()"', intern=TRUE), sep='\n', wait=TRUE)
# Out:
# Warning message in system("python3 -c \"from google.colab import drive\ndrive.mount()\"", :
# “running command 'python3 -c "from google.colab import drive
# drive.mount()"' had status 1”
# TRUE

# %%
system("add-apt-repository -y ppa:marutter/rrutter")
system("add-apt-repository -y ppa:marutter/c2d4u")
system("apt-get update")
system("apt install -y r-cran-rstan")
system('apt-get install libv8-dev') #FOR v8

# %% [markdown]
# ## Libraries

# %%
install.packages('codetools') #Code Analysis Tools for R
install.packages("devtools")
install.packages('data.table') #Fast aggregation of large data (not needed as 20 0000 is a small sample)

install.packages('ggplot2') #for basic charts this is not needed (as has a learning curve)
install.packages('stargazer') #beautiful LATEX, HTML and ASCII tables from R statistical output (not needed as the output is not latex and be used UTF-8)

install.packages('lmtest') #Testing Linear Regression Models

install.packages('dplyr') # A Grammar of Data Manipulation (to replace data.table)

install.packages('mfx') #for marginal effects


# CPA/Corr
install.packages("factoextra")
install.packages("farver")
install.packages('GGally') # corr plot and confusion matrix

#ROC
install.packages('InformationValue')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ## Data

# %%
library(readr)
url <- "/content/Final_table_3.csv"
Finaltable <- read.csv(url, header=TRUE, quote="\"", na.strings = "NA", fill = TRUE )

# %% [markdown]
# ## Data Treatment

# %%
Finaltable$Private_VC_Number[Finaltable$Private_VC_Number < 1] <- 0
Finaltable$Private_VC_Number[Finaltable$Private_VC_Number >= 1] <- 1
Finaltable$Private_VC_Number <- as.factor(Finaltable$Private_VC_Number)

# %% [markdown]
# #DEA

# %%
summary(Finaltable)
# Out:
#  N.Contribuinte.do.Promotor Incorporation_t0 Date_of_first_intervention_t1
#  Min.   :500695679          Min.   :1977     Min.   :2004
#  1st Qu.:508470192          1st Qu.:2008     1st Qu.:2011
#  Median :509967400          Median :2011     Median :2013
#  Mean   :509532181          Mean   :2010     Mean   :2012
#  3rd Qu.:510694812          3rd Qu.:2013     3rd Qu.:2014
#  Max.   :513603980          Max.   :2015     Max.   :2015
#
#  Maximum_Reported_Investment_in_t2  Total_FINOVA     N_Investors_FINOVA
#  Min.   :   35000                  Min.   :      0   Min.   :0.0000
#  1st Qu.:  406000                  1st Qu.:      0   1st Qu.:0.0000
#  Median :  901000                  Median : 363000   Median :1.0000
#  Mean   : 2014029                  Mean   : 693903   Mean   :0.9771
#  3rd Qu.: 1642062                  3rd Qu.:1000000   3rd Qu.:1.0000
#  Max.   :59600000                  Max.   :5890000   Max.   :5.0000
#
#  Total_Increase_in_SC_from_1st_intervention_t1 SC_Final_Intervention_in_t2
#  Min.   :      0                               Min.   :     100
#  1st Qu.:  41700                               1st Qu.:   62500
#  Median :  74400                               Median :   99000
#  Mean   : 360263                               Mean   :  617608
#  3rd Qu.: 207500                               3rd Qu.:  422000
#  Max.   :7900000                               Max.   :18900000
#
#  Total_Increase_SC_Inv Percentage_of_special_class_shares N_Investors_t2
#  Min.   :      0       Min.   :0.0000                     Min.   :1.00
#  1st Qu.:  19580       1st Qu.:0.0000                     1st Qu.:1.00
#  Median :  39245       Median :0.1420                     Median :2.00
#  Mean   : 161302       Mean   :0.2029                     Mean   :2.12
#  3rd Qu.: 108699       3rd Qu.:0.3495                     3rd Qu.:3.00
#  Max.   :2890000       Max.   :1.0000                     Max.   :8.00
#
#                                                                        NACE
#  J - Information and communication                                       :82
#  M - Professional, scientific and technical activities                   :49
#  C - Manufacturing                                                       :22
#  G - Wholesale and retail trade, repair of motor vehicles and motorcycles: 9
#  N - Administrative and support service activities                       : 5
#  K - Financial and insurance activities                                  : 4
#  (Other)                                                                 : 4
#                        Company_not_based_in_PT
#  D ORBIT S.R.L., Italy             :  1
#  DE & MA USA                       :  1
#  DE, USA                           :  1
#  PRINCIPLE POWER, INC., NV USA 2007:  1
#  UNBABEL, INC.2013, DELAWARE (USA) :  1
#  VENIAM, INC., 7/20/2012, DE USA   :  1
#  NA's                              :169
#                                          Exit     Share_Classes
#  2013, share swap to UK LLC                :  1   N      :51
#  2013,DE, USA                              :  1   N - LLC:26
#  Date of Involuntary Revocation, 06-30-2014:  1   Y      :98
#  Dissolution, 20/09/2016                   :  1
#  Dissolution, 2014                         :  1
#  (Other)                                   : 10
#  NA's                                      :160
#  Private_VC_Number Private_VC_Investment QREN_Investimento_Elegivel_N_Operações
#  0: 67             Min.   :       0      Min.   :0.0000
#  1:108             1st Qu.:       0      1st Qu.:0.0000
#                    Median :       0      Median :0.0000
#                    Mean   : 1322812      Mean   :0.5657
#                    3rd Qu.:  603500      3rd Qu.:1.0000
#                    Max.   :59600000      Max.   :6.0000
#
#  QREN_Investimento_Elegivel_Total    QREN_Sector
#  Min.   :       0                 0        :128
#  1st Qu.:       0                 Comercio :  2
#  Median :       0                 Industria: 10
#  Mean   :  329672                 Servicos : 34
#  3rd Qu.:   30729                 Turismo  :  1
#  Max.   :19560891
#
#                                                                                 QREN_CAE_Rev3
#  0                                                                                     :128
#  58290 - Edicao de outros programas informaticos                                       :  5
#  62010 - Actividades de programacao informatica                                        :  5
#  62090 - Outras actividades relacionadas com as tecnologias da informacao e informatica:  4
#  72190 - Outra investigacao e desenvolvimento das ciencias fisicas e naturais          :  4
#  62020 - Actividades de consultoria em informatica                                     :  3
#  (Other)                                                                               : 26
#                                                   QREN_Instrumento
#  SI Qualificacao PME/Projectos Individuais e de Cooperacao: 17
#  I&DT Empresas/Projectos Individuais                      : 11
#  SI Inovacao/Empreendedorismo Qualificado                 :  6
#  SI Qualificacao PME/Vale Inovacao                        :  5
#  I&DT Empresas/Projectos em Co-promocao                   :  3
#  (Other)                                                  :  5
#  NA's                                                     :128
#          QREN_Concelho        QREN_Regiao          QREN_Data_de_Aprovacao
#  0              :128   0            :128   0                  :128
#  Porto          : 10   Alentejo     :  3   2008-04-11 00:00:00:  3
#  Multi-Concelhos:  7   Centro       : 17   2013-02-08 00:00:00:  3
#  Coimbra        :  6   Lisboa       :  4   2013-03-19 00:00:00:  3
#  Cantanhede     :  3   Multi-Regioes:  5   2008-05-05 00:00:00:  2
#  Aveiro         :  2   Norte        : 18   2012-10-17 00:00:00:  2
#  (Other)        : 19                       (Other)            : 34
#   INPI_NICE_N      INPI_modalidade_N         INPI_modalidade_Moda
#  Min.   : 0.0000   Min.   : 0.0000   0                 :130
#  1st Qu.: 0.0000   1st Qu.: 0.0000   Logotype          :  2
#  Median : 0.0000   Median : 0.0000   National Trademark: 43
#  Mean   : 0.7886   Mean   : 0.7886
#  3rd Qu.: 1.0000   3rd Qu.: 1.0000
#  Max.   :12.0000   Max.   :12.0000
#
#         INPI_NICE_moda          INPI_dt_ini_vigencia
#  0             :130    0                  :130
#  09            :  6    2009-02-20 00:00:00:  2
#  42            :  6    2010-12-27 00:00:00:  2
#  NOT APPLICABLE:  4    2015-02-02 00:00:00:  2
#  09 42         :  2    2015-09-14 00:00:00:  2
#  11            :  2    2004-10-29 00:00:00:  1
#  (Other)       : 25    (Other)            : 36
#              INPI_Patents_ipc INPI_Patents_ipc_count     INPI.Patents_moda_mode
#  0                   :172     Min.   :0.00000        0              :172
#  A23J 1/12 (2006.01) :  1     1st Qu.:0.00000        National Patent:  3
#  B01F 5/00 (1968.09) :  1     Median :0.00000
#  E04F 13/14 (2006.01):  1     Mean   :0.05143
#                               3rd Qu.:0.00000
#                               Max.   :5.00000
#
#            INPI_Patents_date INPI_Design_moda      INPI_Design_moda_count
#  0                  :172     Min.   :0.00000   0              :174
#  2004-02-13 00:00:00:  1     1st Qu.:0.00000   National Design:  1
#  2006-10-06 00:00:00:  1     Median :0.00000
#  2007-10-19 00:00:00:  1     Mean   :0.01143
#                              3rd Qu.:0.00000
#                              Max.   :2.00000
#
#          INPI_Design_fase_actual            INPI_Design_date      IPR
#  0                   :174        0                  :174     Min.   : 0.00
#  REGISTRATION GRANTED:  1        2014-04-28 00:00:00:  1     1st Qu.: 0.00
#                                                              Median : 0.00
#                                                              Mean   : 0.84
#                                                              3rd Qu.: 1.00
#                                                              Max.   :12.00
#
#      IPR_P            FINOVA            QREN        in_degree_centrality
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.0000   Min.   :0.005405
#  1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.005405
#  Median :0.0000   Median :1.0000   Median :0.0000   Median :0.005405
#  Mean   :0.1943   Mean   :0.6914   Mean   :0.2686   Mean   :0.007598
#  3rd Qu.:0.0000   3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:0.010811
#  Max.   :1.0000   Max.   :1.0000   Max.   :1.0000   Max.   :0.016216
#
#  eigenvector_centrality
#  Min.   :0.05335
#  1st Qu.:0.05335
#  Median :0.05335
#  Mean   :0.07139
#  3rd Qu.:0.09782
#  Max.   :0.14228

# %% [markdown]
# #### Correlation Matrix

# %%
library(GGally)

corr <- data.frame(lapply(Finaltable, as.integer))
# Plot the graphggcorr(using GGally)
ggcorr(corr, method = c("everything", "spearman"), nbreaks = 6,
hjust = 0.8,label = TRUE, label_size = 3, color = "grey50")
# Out:
# Warning message in cor(data, use = method[1], method = method[2]):
# “the standard deviation is zero”
# plot without title

# %% [markdown]
# ## Dependent (response) Variable
#
# ### IPR P (Existance of IPR) >=1
#
# * Frequency table (dependant variable)

# %%
table <- table(Finaltable$IPR_P)
table
# Out:
#   0   1
# 141  34

# %% [markdown]
# * Proportions

# %%
prop.table(table)
# Out:
#         0         1
# 0.8057143 0.1942857

# %%
library(ggplot2)
options(repr.plot.width=8, repr.plot.height=8)
g <- ggplot(Finaltable, aes(Finaltable$IPR_P))
g + geom_bar() + labs(title= "IPR \ (0 = No and 1 = Yes)",  y="Count", x = "Response")
# Out:
# Warning message:
# “Use of `Finaltable$IPR_P` is discouraged. Use `IPR_P` instead.”
# plot without title

# %%
library(ggplot2)
# Make plots wider 
options(repr.plot.width=15, repr.plot.height=8)
g1 <- ggplot(Finaltable, aes(IPR, fill= INPI_NICE_moda))
g1 + geom_bar(width=0.8) + labs(title= "Trademark Number per entity",  y="Count", x = "Number per entity")
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
g2 <- ggplot(Finaltable, aes(INPI_Patents_ipc_count, fill=INPI_Patents_ipc))
g2 + geom_bar() + labs(title= "Number of Patents per Entity",  y="Count", x = "Response")
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)
g3 <- ggplot(Finaltable, aes(INPI_Design_moda_count, fill=INPI_Design_moda))
g3 + geom_bar() + labs(title= "Design",  y="Count", x = "Response")
# Out:
# plot without title

# %% [markdown]
# ## Predictors
#
# ### QREN

# %%
table3 <- table(Finaltable$QREN)
table3
# Out:
#   0   1
# 128  47

# %%
prop.table(table3)
# Out:
#         0         1
# 0.7314286 0.2685714

# %%
QREN_Instrumento <-ggplot(Finaltable, aes(x = QREN_Instrumento, fill=QREN_Instrumento)) + geom_bar() + coord_flip() + ggtitle("QREN_Instrumento") + xlab("") + scale_fill_brewer(palette="Spectral") + labs(x = "QREN_Instrumento", fill = "Legenda") + theme_classic() + theme(legend.position="none") + theme(axis.title = element_text(size = rel(1), colour = "grey")) + theme(plot.title = element_text(size = 10, vjust = 2, colour = "steelblue", face = "bold")) + theme(axis.title = element_text(size = rel(1), colour = "grey"))

QREN_Instrumento
# Out:
# plot without title

# %% [markdown]
# #### Transformation (-> log)

# %%
Finaltable$QREN_Investimento_Elegivel_Total_log <- log(Finaltable$QREN_Investimento_Elegivel_Total)

# %%
# Histogram with kernel density curve
ggplot(Finaltable, aes(x = QREN_Investimento_Elegivel_Total_log)) +
    geom_density(alpha = .2, fill = "#FF6666")
# Out:
# Warning message:
# “Removed 128 rows containing non-finite values (stat_density).”
# plot without title

# %%
# ecdf
Total.aum.inv_ecdf <- ggplot(Finaltable, aes(QREN_Investimento_Elegivel_Total_log)) + stat_ecdf(geom = "point", colour = "steelblue") +  ylab("Fn") + ggtitle("QREN_Investimento_Elegivel_Total_log") 

Total.aum.inv_ecdf
# Out:
# Warning message:
# “Removed 128 rows containing non-finite values (stat_ecdf).”
# plot without title

# %% [markdown]
# ### FIN0VA

# %%
table4 <- table(Finaltable$FINOVA)
table4
# Out:
#   0   1
#  54 121

# %%
prop.table(table4)
# Out:
#         0         1
# 0.3085714 0.6914286

# %%
options(repr.plot.width=8, repr.plot.height=8)
g4 <- ggplot(Finaltable, aes(x= N_Investors_t2,y= N_Investors_FINOVA)) 
g4 + geom_col(aes(fill = Private_VC_Number), width = 0.7) + labs(title= "Number of Investors per type")
# Out:
# plot without title

# %% [markdown]
# ### Network measures (In Degree Centrality)

# %%
# Histogram with kernel density curve
ggplot(Finaltable, aes(x = in_degree_centrality)) +
    geom_density(alpha = .2, fill = "#FF6666")
# Out:
# plot without title

# %%
# ecdf
in_degree_centrality_ecdf <- ggplot(Finaltable, aes(in_degree_centrality)) + stat_ecdf(geom = "point", colour = "steelblue") +  ylab("Fn") + ggtitle("in_degree_centrality") + theme(axis.title = element_text(size = rel(0.75), colour = "grey")) + theme(axis.title = element_text(size = rel(0.75), colour = "grey"))

in_degree_centrality_ecdf
# Out:
# plot without title

# %% [markdown]
# ### NACE

# %%
table5 <- table(Finaltable$NACE)
table5
# Out:
#                                                        C - Manufacturing
#                                                                       22
#                  D - Electricity, gas, steam and air conditioning supply
#                                                                        1
#                                                         F - Construction
#                                                                        1
# G - Wholesale and retail trade, repair of motor vehicles and motorcycles
#                                                                        9
#                                        J - Information and communication
#                                                                       82
#                                   K - Financial and insurance activities
#                                                                        4
#                                               L - Real estate activities
#                                                                        1
#                    M - Professional, scientific and technical activities
#                                                                       49
#                        N - Administrative and support service activities
#                                                                        5
#                                   R - Arts, entertainment and recreation
#                                                                        1

# %%
prop.table(table5)
# Out:
#                                                        C - Manufacturing
#                                                              0.125714286
#                  D - Electricity, gas, steam and air conditioning supply
#                                                              0.005714286
#                                                         F - Construction
#                                                              0.005714286
# G - Wholesale and retail trade, repair of motor vehicles and motorcycles
#                                                              0.051428571
#                                        J - Information and communication
#                                                              0.468571429
#                                   K - Financial and insurance activities
#                                                              0.022857143
#                                               L - Real estate activities
#                                                              0.005714286
#                    M - Professional, scientific and technical activities
#                                                              0.280000000
#                        N - Administrative and support service activities
#                                                              0.028571429
#                                   R - Arts, entertainment and recreation
#                                                              0.005714286

# %%
NACE <-ggplot(Finaltable, aes(x = NACE, fill=NACE)) + geom_bar() + coord_flip() + ggtitle("NACE") + xlab("") + scale_fill_brewer(palette="Spectral") + labs(x = "CAE", fill = "Legenda") + theme_classic() + theme(legend.position="none") + theme(axis.title = element_text(size = rel(1), colour = "grey")) + theme(plot.title = element_text(size = 10, vjust = 2, colour = "steelblue", face = "bold")) + theme(axis.title = element_text(size = rel(1), colour = "grey"))
NACE
# Out:
# plot without title

# %%
summary(Finaltable$NACE)
# Out:
#                                                        C - Manufacturing
#                                                                       22
#                  D - Electricity, gas, steam and air conditioning supply
#                                                                        1
#                                                         F - Construction
#                                                                        1
# G - Wholesale and retail trade, repair of motor vehicles and motorcycles
#                                                                        9
#                                        J - Information and communication
#                                                                       82
#                                   K - Financial and insurance activities
#                                                                        4
#                                               L - Real estate activities
#                                                                        1
#                    M - Professional, scientific and technical activities
#                                                                       49
#                        N - Administrative and support service activities
#                                                                        5
#                                   R - Arts, entertainment and recreation
#                                                                        1

# %%
g5 <- ggplot(Finaltable, aes(x= N_Investors_t2,y= QREN)) 
g5 + geom_col(aes(fill = FINOVA), width = 0.7) + labs(title= "Public")
# Out:
# plot without title

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
Finaltable$in_degree_centrality100 <- Finaltable$in_degree_centrality*100

# %%
library(GGally)
plist <- c('IPR_P', 'IPR', "QREN_Investimento_Elegivel_Total", "N_Investors_FINOVA","Total_FINOVA", "in_degree_centrality100")
newdata <- Finaltable[plist]
#"NACE"
corr1 <- data.frame(lapply(newdata, as.integer))
# Plot the graphggcorr(using GGally)
ggcorr(corr1, method = c("everything", "spearman"), nbreaks = 6,
hjust = 0.8,label = TRUE, label_size = 3, color = "grey50")
# Out:
# plot without title

# %%
library(magrittr) # for pipe %>%
library(dplyr)   # everything else
library(farver)
library(factoextra)
res.pca <- prcomp(corr1, scale = TRUE)
fviz_eig(res.pca)
# Out:
# plot without title

# %%
summary(res.pca)
# Out:
# Importance of components:
#                           PC1    PC2    PC3     PC4     PC5     PC6
# Standard deviation     1.6736 1.1576 0.8631 0.73055 0.62487 0.43564
# Proportion of Variance 0.4668 0.2233 0.1242 0.08895 0.06508 0.03163
# Cumulative Proportion  0.4668 0.6902 0.8143 0.90329 0.96837 1.00000

# %%
library(farver)
fviz_pca_ind(res.pca,
             col.ind = "cos2", # Color by the quality of representation
             gradient.cols = c('#00AFBB', '#E7B000','#FC4E07'),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
groups <- as.factor(newdata$IPR_P[1:175])
fviz_pca_ind(res.pca,
             col.ind = groups, # color by groups
             palette = c("#00AFBB",  "#FC4E07"),
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             legend.title = "Groups",
             repel = TRUE
             )
# Out:
# plot without title

# %%
library(magrittr) # for pipe %>%
library(dplyr)   # everything else
library(farver)
fviz_pca_var(res.pca,
             col.var = "contrib", # Color by contributions to the PC
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
             repel = TRUE     # Avoid text overlapping
             )
# Out:
# plot without title

# %%
fviz_pca_biplot(res.pca, repel = TRUE,
                col.var = "#2E9FDF", # Variables color
                col.ind = "#696969"  # Individuals color
                )
# Out:
# plot without title

# %% [markdown]
# ## Probit Regression
#
# A probit regression is a version of the generalized linear model used to model dichotomous outcome variables. It uses the inverse standard normal distribution as a linear combination of the predictors. The binary outcome variable Y is assumed to have a Bernoulli distribution with parameter $p$ (where the success probability is $p\in(0,1)$). Hence, the probit link function is
#
# $$\Phi^{-1}(\pi_{i}) = X_{i}\beta + \varepsilon _{i}$$
#
# where
#
# $$\Phi(Z) = \int_{-\propto}^{Z}\frac{1}{\sqrt2\pi}e^{\frac{1}{2}t^{2}}dt.$$
#
#
# This is the cumulative normal distribution
# $\Phi$ That is, given any Z-score, $\Phi(Z)\in[0,1]$
#
# So we would say that
# $$Y =\Phi(X\beta + \varepsilon)$$
# $$\Phi^{-1}(Y)= X\beta + \varepsilon$$
# $$Y′ = X\beta + \varepsilon$$
#
# Link function is $F(Y)=\Phi^{-1}(Y)$

# %%
No_Predictor <-glm(Finaltable$IPR_P~1,Finaltable,family = binomial(link= "probit"))
summary(No_Predictor)
# Out:
# Call:
# glm(formula = Finaltable$IPR_P ~ 1, family = binomial(link = "probit"),
#     data = Finaltable)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.6573  -0.6573  -0.6573  -0.6573   1.8102
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -0.8622     0.1087  -7.931 2.18e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 172.33  on 174  degrees of freedom
# Residual deviance: 172.33  on 174  degrees of freedom
# AIC: 174.33
#
# Number of Fisher Scoring iterations: 4

# %%
library(stargazer)
stargazer(No_Predictor, type = 'text', no.space = TRUE)
# Out:
# Please cite as:
#
#
#  Hlavac, Marek (2018). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.2. https://CRAN.R-project.org/package=stargazer
# =============================================
#                       Dependent variable:
#                   ---------------------------
#                              IPR_P
# ---------------------------------------------
# Constant                   -0.862***
#                             (0.109)
# ---------------------------------------------
# Observations                  175
# Log Likelihood              -86.166
# Akaike Inf. Crit.           174.332
# =============================================
# Note:             *p<0.1; **p<0.05; ***p<0.01

# %%
Probit = glm(Finaltable$IPR_P ~ Finaltable$QREN_Investimento_Elegivel_Total + Finaltable$N_Investors_FINOVA  + Finaltable$in_degree_centrality + Finaltable$NACE, data= Finaltable, binomial(link= "probit"))
summary(Probit)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Finaltable$IPR_P ~ Finaltable$QREN_Investimento_Elegivel_Total +
#     Finaltable$N_Investors_FINOVA + Finaltable$in_degree_centrality +
#     Finaltable$NACE, family = binomial(link = "probit"), data = Finaltable)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -2.50600  -0.16342  -0.08589  -0.04592   1.95374
#
# Coefficients:
#                                                                                           Estimate
# (Intercept)                                                                             -3.887e+00
# Finaltable$QREN_Investimento_Elegivel_Total                                              2.067e-06
# Finaltable$N_Investors_FINOVA                                                            3.947e-01
# Finaltable$in_degree_centrality                                                          2.357e+02
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -2.963e+00
# Finaltable$NACEF - Construction                                                          6.312e+00
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -1.854e-01
# Finaltable$NACEJ - Information and communication                                        -4.616e-01
# Finaltable$NACEK - Financial and insurance activities                                   -3.497e+00
# Finaltable$NACEL - Real estate activities                                               -2.963e+00
# Finaltable$NACEM - Professional, scientific and technical activities                    -1.907e-01
# Finaltable$NACEN - Administrative and support service activities                         9.520e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   -2.963e+00
#                                                                                         Std. Error
# (Intercept)                                                                              8.386e-01
# Finaltable$QREN_Investimento_Elegivel_Total                                              5.748e-07
# Finaltable$N_Investors_FINOVA                                                            1.845e-01
# Finaltable$in_degree_centrality                                                          6.664e+01
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                   9.735e+02
# Finaltable$NACEF - Construction                                                          9.735e+02
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles  7.998e-01
# Finaltable$NACEJ - Information and communication                                         5.123e-01
# Finaltable$NACEK - Financial and insurance activities                                    4.645e+02
# Finaltable$NACEL - Real estate activities                                                9.735e+02
# Finaltable$NACEM - Professional, scientific and technical activities                     5.673e-01
# Finaltable$NACEN - Administrative and support service activities                         8.952e-01
# Finaltable$NACER - Arts, entertainment and recreation                                    9.735e+02
#                                                                                         z value
# (Intercept)                                                                              -4.636
# Finaltable$QREN_Investimento_Elegivel_Total                                               3.596
# Finaltable$N_Investors_FINOVA                                                             2.139
# Finaltable$in_degree_centrality                                                           3.537
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                   -0.003
# Finaltable$NACEF - Construction                                                           0.006
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles  -0.232
# Finaltable$NACEJ - Information and communication                                         -0.901
# Finaltable$NACEK - Financial and insurance activities                                    -0.008
# Finaltable$NACEL - Real estate activities                                                -0.003
# Finaltable$NACEM - Professional, scientific and technical activities                     -0.336
# Finaltable$NACEN - Administrative and support service activities                          1.063
# Finaltable$NACER - Arts, entertainment and recreation                                    -0.003
#                                                                                         Pr(>|z|)
# (Intercept)                                                                             3.56e-06
# Finaltable$QREN_Investimento_Elegivel_Total                                             0.000323
# Finaltable$N_Investors_FINOVA                                                           0.032407
# Finaltable$in_degree_centrality                                                         0.000404
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  0.997572
# Finaltable$NACEF - Construction                                                         0.994826
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 0.816680
# Finaltable$NACEJ - Information and communication                                        0.367626
# Finaltable$NACEK - Financial and insurance activities                                   0.993993
# Finaltable$NACEL - Real estate activities                                               0.997572
# Finaltable$NACEM - Professional, scientific and technical activities                    0.736754
# Finaltable$NACEN - Administrative and support service activities                        0.287593
# Finaltable$NACER - Arts, entertainment and recreation                                   0.997572
#
# (Intercept)                                                                             ***
# Finaltable$QREN_Investimento_Elegivel_Total                                             ***
# Finaltable$N_Investors_FINOVA                                                           *
# Finaltable$in_degree_centrality                                                         ***
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply
# Finaltable$NACEF - Construction
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles
# Finaltable$NACEJ - Information and communication
# Finaltable$NACEK - Financial and insurance activities
# Finaltable$NACEL - Real estate activities
# Finaltable$NACEM - Professional, scientific and technical activities
# Finaltable$NACEN - Administrative and support service activities
# Finaltable$NACER - Arts, entertainment and recreation
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 172.332  on 174  degrees of freedom
# Residual deviance:  64.994  on 162  degrees of freedom
# AIC: 90.994
#
# Number of Fisher Scoring iterations: 16

# %%
library(stargazer)
stargazer(Probit, type = 'text', no.space = TRUE)
# Out:
# ========================================================================================================
#                                                                                  Dependent variable:
#                                                                              ---------------------------
#                                                                                         IPR_P
# --------------------------------------------------------------------------------------------------------
# QREN_Investimento_Elegivel_Total                                                     0.00000***
#                                                                                       (0.00000)
# N_Investors_FINOVA                                                                     0.395**
#                                                                                        (0.185)
# in_degree_centrality                                                                 235.747***
#                                                                                       (66.644)
# NACED - Electricity, gas, steam and air conditioning supply                            -2.963
#                                                                                       (973.498)
# NACEF - Construction                                                                    6.312
#                                                                                       (973.498)
# NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles           -0.185
#                                                                                        (0.800)
# NACEJ - Information and communication                                                  -0.462
#                                                                                        (0.512)
# NACEK - Financial and insurance activities                                             -3.497
#                                                                                       (464.498)
# NACEL - Real estate activities                                                         -2.963
#                                                                                       (973.498)
# NACEM - Professional, scientific and technical activities                              -0.191
#                                                                                        (0.567)
# NACEN - Administrative and support service activities                                   0.952
#                                                                                        (0.895)
# NACER - Arts, entertainment and recreation                                             -2.963
#                                                                                       (973.498)
# Constant                                                                              -3.887***
#                                                                                        (0.839)
# --------------------------------------------------------------------------------------------------------
# Observations                                                                             175
# Log Likelihood                                                                         -32.497
# Akaike Inf. Crit.                                                                      90.994
# ========================================================================================================
# Note:                                                                        *p<0.1; **p<0.05; ***p<0.01

# %%
Finaltable %>% 
  ggplot(aes(x = QREN_Investimento_Elegivel_Total, y = IPR_P)) + 
  geom_point() +
  geom_smooth(method = "glm", method.args=list(family=binomial(link = "probit")), se = F) + 
  ggtitle("Probit")
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# plot without title

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.1     ✔ stringr 1.4.0
# ✔ tidyr   1.1.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ tidyr::extract()   masks magrittr::extract()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ purrr::set_names() masks magrittr::set_names()

# %%
Finaltable %>% 
  ggplot(aes(x = Total_FINOVA, y = IPR_P)) + 
  geom_point() +
  geom_smooth(method = "glm", method.args=list(family=binomial(link = "probit")), se = F) + 
  ggtitle("Probit")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
Finaltable %>% 
  ggplot(aes(x = in_degree_centrality, y = IPR_P)) + 
  geom_point() +
  geom_smooth(method = "glm", method.args=list(family=binomial(link = "probit")), se = F) + 
  ggtitle("Probit")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
confint(Probit)
# Out:
# Waiting for profiling to be done...
#
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
#                                                                                         2.5 %
# (Intercept)                                                                             -5.830658e+00
# Finaltable$QREN_Investimento_Elegivel_Total                                              1.138277e-06
# Finaltable$N_Investors_FINOVA                                                            2.301289e-02
# Finaltable$in_degree_centrality                                                          1.153783e+02
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                             NA
# Finaltable$NACEF - Construction                                                         -1.919371e+02
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -1.674049e+00
# Finaltable$NACEJ - Information and communication                                        -1.468520e+00
# Finaltable$NACEK - Financial and insurance activities                                              NA
# Finaltable$NACEL - Real estate activities                                                          NA
# Finaltable$NACEM - Professional, scientific and technical activities                    -1.310927e+00
# Finaltable$NACEN - Administrative and support service activities                        -9.291837e-01
# Finaltable$NACER - Arts, entertainment and recreation                                              NA
#                                                                                         97.5 %
# (Intercept)                                                                             -2.409840e+00
# Finaltable$QREN_Investimento_Elegivel_Total                                              3.124751e-06
# Finaltable$N_Investors_FINOVA                                                            7.731372e-01
# Finaltable$in_degree_centrality                                                          3.802987e+02
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                   1.950802e+02
# Finaltable$NACEF - Construction                                                                    NA
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles  1.276806e+00
# Finaltable$NACEJ - Information and communication                                         5.602451e-01
# Finaltable$NACEK - Financial and insurance activities                                    4.895463e+01
# Finaltable$NACEL - Real estate activities                                                1.950802e+02
# Finaltable$NACEM - Professional, scientific and technical activities                     9.533899e-01
# Finaltable$NACEN - Administrative and support service activities                         2.821518e+00
# Finaltable$NACER - Arts, entertainment and recreation                                    1.950802e+02

# %% [markdown]
# The estimated model equation is
#
#
# * (constant) given that all predictors are set to their mean values.

# %% [markdown]
# ### Marginal Effects

# %% [markdown]
# #### Marginal effects interpretation:
#
# * It is interpreted as both the sign and the magnitude of the marginal effects.
#
# * The marginal effects at the mean and the average marginal effects are almost identical.
#
# * An increase in x increases (decreases) the probability that y=1 by the marginal effect expressed as a percent.
#  - For dummy independent variables, the marginal effect is expressed in comparison to the base category (x=0).
#  - For continuous independent variables, the marginal effect is expressed for a one-unit change in x.

# %% [markdown]
# ### Using Partial Effects at the Average (PEA):

# %%
library("mfx")
#probitmfx(dataPTsample_imp$dataPT.Y16_Q89a ~ dataPTsample_imp$dataPT.Y16_Q93b + dataPTsample_imp$dataPT.Y16_Income_Equivalised_log, dataPTsample_imp)
PEA_probit = mfx::probitmfx(formula = Probit$formula, data = Probit$data, atmean = TRUE)
print(PEA_probit$mfxest)
# Out:
# Loading required package: sandwich
#
# Loading required package: lmtest
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: betareg
#
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
#                                                                                                 dF/dx
# Finaltable$QREN_Investimento_Elegivel_Total                                              3.201886e-07
# Finaltable$N_Investors_FINOVA                                                            6.113948e-02
# Finaltable$in_degree_centrality                                                          3.651542e+01
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -8.712407e-02
# Finaltable$NACEF - Construction                                                          9.209702e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -2.556773e-02
# Finaltable$NACEJ - Information and communication                                        -7.064716e-02
# Finaltable$NACEK - Financial and insurance activities                                   -9.755085e-02
# Finaltable$NACEL - Real estate activities                                               -8.712407e-02
# Finaltable$NACEM - Professional, scientific and technical activities                    -2.789756e-02
# Finaltable$NACEN - Administrative and support service activities                         2.457322e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   -8.712407e-02
#                                                                                            Std. Err.
# Finaltable$QREN_Investimento_Elegivel_Total                                             6.775308e-06
# Finaltable$N_Investors_FINOVA                                                           1.293762e+00
# Finaltable$in_degree_centrality                                                         7.725189e+02
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  2.272868e+00
# Finaltable$NACEF - Construction                                                         2.112181e+00
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 5.802244e-01
# Finaltable$NACEJ - Information and communication                                        1.485916e+00
# Finaltable$NACEK - Financial and insurance activities                                   1.917932e+00
# Finaltable$NACEL - Real estate activities                                               2.272868e+00
# Finaltable$NACEM - Professional, scientific and technical activities                    6.114617e-01
# Finaltable$NACEN - Administrative and support service activities                        3.263862e+00
# Finaltable$NACER - Arts, entertainment and recreation                                   2.272868e+00
#                                                                                                   z
# Finaltable$QREN_Investimento_Elegivel_Total                                              0.04725816
# Finaltable$N_Investors_FINOVA                                                            0.04725712
# Finaltable$in_degree_centrality                                                          0.04726800
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -0.03833221
# Finaltable$NACEF - Construction                                                          0.43602815
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -0.04406525
# Finaltable$NACEJ - Information and communication                                        -0.04754451
# Finaltable$NACEK - Financial and insurance activities                                   -0.05086252
# Finaltable$NACEL - Real estate activities                                               -0.03833221
# Finaltable$NACEM - Professional, scientific and technical activities                    -0.04562437
# Finaltable$NACEN - Administrative and support service activities                         0.07528879
# Finaltable$NACER - Arts, entertainment and recreation                                   -0.03833221
#                                                                                             P>|z|
# Finaltable$QREN_Investimento_Elegivel_Total                                             0.9623075
# Finaltable$N_Investors_FINOVA                                                           0.9623083
# Finaltable$in_degree_centrality                                                         0.9622996
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  0.9694228
# Finaltable$NACEF - Construction                                                         0.6628163
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 0.9648524
# Finaltable$NACEJ - Information and communication                                        0.9620793
# Finaltable$NACEK - Financial and insurance activities                                   0.9594351
# Finaltable$NACEL - Real estate activities                                               0.9694228
# Finaltable$NACEM - Professional, scientific and technical activities                    0.9636096
# Finaltable$NACEN - Administrative and support service activities                        0.9399849
# Finaltable$NACER - Arts, entertainment and recreation                                   0.9694228

# %%
PEA_probit$mfxest
# Out:
#                                                                                         dF/dx
# Finaltable$QREN_Investimento_Elegivel_Total                                              3.201886e-07
# Finaltable$N_Investors_FINOVA                                                            6.113948e-02
# Finaltable$in_degree_centrality                                                          3.651542e+01
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -8.712407e-02
# Finaltable$NACEF - Construction                                                          9.209702e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -2.556773e-02
# Finaltable$NACEJ - Information and communication                                        -7.064716e-02
# Finaltable$NACEK - Financial and insurance activities                                   -9.755085e-02
# Finaltable$NACEL - Real estate activities                                               -8.712407e-02
# Finaltable$NACEM - Professional, scientific and technical activities                    -2.789756e-02
# Finaltable$NACEN - Administrative and support service activities                         2.457322e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   -8.712407e-02
#                                                                                         Std. Err.
# Finaltable$QREN_Investimento_Elegivel_Total                                             6.775308e-06
# Finaltable$N_Investors_FINOVA                                                           1.293762e+00
# Finaltable$in_degree_centrality                                                         7.725189e+02
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  2.272868e+00
# Finaltable$NACEF - Construction                                                         2.112181e+00
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 5.802244e-01
# Finaltable$NACEJ - Information and communication                                        1.485916e+00
# Finaltable$NACEK - Financial and insurance activities                                   1.917932e+00
# Finaltable$NACEL - Real estate activities                                               2.272868e+00
# Finaltable$NACEM - Professional, scientific and technical activities                    6.114617e-01
# Finaltable$NACEN - Administrative and support service activities                        3.263862e+00
# Finaltable$NACER - Arts, entertainment and recreation                                   2.272868e+00
#                                                                                         z
# Finaltable$QREN_Investimento_Elegivel_Total                                              0.04725816
# Finaltable$N_Investors_FINOVA                                                            0.04725712
# Finaltable$in_degree_centrality                                                          0.04726800
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -0.03833221
# Finaltable$NACEF - Construction                                                          0.43602815
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -0.04406525
# Finaltable$NACEJ - Information and communication                                        -0.04754451
# Finaltable$NACEK - Financial and insurance activities                                   -0.05086252
# Finaltable$NACEL - Real estate activities                                               -0.03833221
# Finaltable$NACEM - Professional, scientific and technical activities                    -0.04562437
# Finaltable$NACEN - Administrative and support service activities                         0.07528879
# Finaltable$NACER - Arts, entertainment and recreation                                   -0.03833221
#                                                                                         P>|z|
# Finaltable$QREN_Investimento_Elegivel_Total                                             0.9623075
# Finaltable$N_Investors_FINOVA                                                           0.9623083
# Finaltable$in_degree_centrality                                                         0.9622996
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  0.9694228
# Finaltable$NACEF - Construction                                                         0.6628163
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 0.9648524
# Finaltable$NACEJ - Information and communication                                        0.9620793
# Finaltable$NACEK - Financial and insurance activities                                   0.9594351
# Finaltable$NACEL - Real estate activities                                               0.9694228
# Finaltable$NACEM - Professional, scientific and technical activities                    0.9636096
# Finaltable$NACEN - Administrative and support service activities                        0.9399849
# Finaltable$NACER - Arts, entertainment and recreation                                   0.9694228

# %% [markdown]
# ### Using Average Partial Effect (APE)

# %%
APE_probit = mfx::probitmfx(formula = Probit$formula, data = Probit$data, atmean = FALSE)
print(APE_probit$mfxest)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
#                                                                                                 dF/dx
# Finaltable$QREN_Investimento_Elegivel_Total                                              2.060001e-07
# Finaltable$N_Investors_FINOVA                                                            3.933538e-02
# Finaltable$in_degree_centrality                                                          2.349297e+01
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -1.421274e-01
# Finaltable$NACEF - Construction                                                          8.044045e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -1.772521e-02
# Finaltable$NACEJ - Information and communication                                        -4.666959e-02
# Finaltable$NACEK - Financial and insurance activities                                   -1.489010e-01
# Finaltable$NACEL - Real estate activities                                               -1.421274e-01
# Finaltable$NACEM - Professional, scientific and technical activities                    -1.874373e-02
# Finaltable$NACEN - Administrative and support service activities                         1.177615e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   -1.421274e-01
#                                                                                            Std. Err.
# Finaltable$QREN_Investimento_Elegivel_Total                                             4.818787e-08
# Finaltable$N_Investors_FINOVA                                                           1.750832e-02
# Finaltable$in_degree_centrality                                                         5.941121e+00
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  1.364956e+01
# Finaltable$NACEF - Construction                                                         1.386054e+01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 7.327663e-02
# Finaltable$NACEJ - Information and communication                                        5.209757e-02
# Finaltable$NACEK - Financial and insurance activities                                   4.962770e+00
# Finaltable$NACEL - Real estate activities                                               1.364956e+01
# Finaltable$NACEM - Professional, scientific and technical activities                    5.485256e-02
# Finaltable$NACEN - Administrative and support service activities                        1.340620e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   1.364956e+01
#                                                                                                   z
# Finaltable$QREN_Investimento_Elegivel_Total                                              4.27493710
# Finaltable$N_Investors_FINOVA                                                            2.24666742
# Finaltable$in_degree_centrality                                                          3.95429943
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -0.01041260
# Finaltable$NACEF - Construction                                                          0.05803560
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -0.24189451
# Finaltable$NACEJ - Information and communication                                        -0.89581127
# Finaltable$NACEK - Financial and insurance activities                                   -0.03000361
# Finaltable$NACEL - Real estate activities                                               -0.01041260
# Finaltable$NACEM - Professional, scientific and technical activities                    -0.34171108
# Finaltable$NACEN - Administrative and support service activities                         0.87841083
# Finaltable$NACER - Arts, entertainment and recreation                                   -0.01041260
#                                                                                                P>|z|
# Finaltable$QREN_Investimento_Elegivel_Total                                             1.911913e-05
# Finaltable$N_Investors_FINOVA                                                           2.466129e-02
# Finaltable$in_degree_centrality                                                         7.675923e-05
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  9.916921e-01
# Finaltable$NACEF - Construction                                                         9.537203e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 8.088619e-01
# Finaltable$NACEJ - Information and communication                                        3.703536e-01
# Finaltable$NACEK - Financial and insurance activities                                   9.760642e-01
# Finaltable$NACEL - Real estate activities                                               9.916921e-01
# Finaltable$NACEM - Professional, scientific and technical activities                    7.325683e-01
# Finaltable$NACEN - Administrative and support service activities                        3.797208e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   9.916921e-01

# %%
APE_probit$mfxest
# Out:
#                                                                                         dF/dx
# Finaltable$QREN_Investimento_Elegivel_Total                                              2.060001e-07
# Finaltable$N_Investors_FINOVA                                                            3.933538e-02
# Finaltable$in_degree_centrality                                                          2.349297e+01
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -1.421274e-01
# Finaltable$NACEF - Construction                                                          8.044045e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -1.772521e-02
# Finaltable$NACEJ - Information and communication                                        -4.666959e-02
# Finaltable$NACEK - Financial and insurance activities                                   -1.489010e-01
# Finaltable$NACEL - Real estate activities                                               -1.421274e-01
# Finaltable$NACEM - Professional, scientific and technical activities                    -1.874373e-02
# Finaltable$NACEN - Administrative and support service activities                         1.177615e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   -1.421274e-01
#                                                                                         Std. Err.
# Finaltable$QREN_Investimento_Elegivel_Total                                             4.818787e-08
# Finaltable$N_Investors_FINOVA                                                           1.750832e-02
# Finaltable$in_degree_centrality                                                         5.941121e+00
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  1.364956e+01
# Finaltable$NACEF - Construction                                                         1.386054e+01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 7.327663e-02
# Finaltable$NACEJ - Information and communication                                        5.209757e-02
# Finaltable$NACEK - Financial and insurance activities                                   4.962770e+00
# Finaltable$NACEL - Real estate activities                                               1.364956e+01
# Finaltable$NACEM - Professional, scientific and technical activities                    5.485256e-02
# Finaltable$NACEN - Administrative and support service activities                        1.340620e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   1.364956e+01
#                                                                                         z
# Finaltable$QREN_Investimento_Elegivel_Total                                              4.27493710
# Finaltable$N_Investors_FINOVA                                                            2.24666742
# Finaltable$in_degree_centrality                                                          3.95429943
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -0.01041260
# Finaltable$NACEF - Construction                                                          0.05803560
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -0.24189451
# Finaltable$NACEJ - Information and communication                                        -0.89581127
# Finaltable$NACEK - Financial and insurance activities                                   -0.03000361
# Finaltable$NACEL - Real estate activities                                               -0.01041260
# Finaltable$NACEM - Professional, scientific and technical activities                    -0.34171108
# Finaltable$NACEN - Administrative and support service activities                         0.87841083
# Finaltable$NACER - Arts, entertainment and recreation                                   -0.01041260
#                                                                                         P>|z|
# Finaltable$QREN_Investimento_Elegivel_Total                                             1.911913e-05
# Finaltable$N_Investors_FINOVA                                                           2.466129e-02
# Finaltable$in_degree_centrality                                                         7.675923e-05
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  9.916921e-01
# Finaltable$NACEF - Construction                                                         9.537203e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 8.088619e-01
# Finaltable$NACEJ - Information and communication                                        3.703536e-01
# Finaltable$NACEK - Financial and insurance activities                                   9.760642e-01
# Finaltable$NACEL - Real estate activities                                               9.916921e-01
# Finaltable$NACEM - Professional, scientific and technical activities                    7.325683e-01
# Finaltable$NACEN - Administrative and support service activities                        3.797208e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   9.916921e-01

# %% [markdown]
# * The interpretation of PEA and APE of the probit model are analogous to the logit model - a unit increase in the (average, if PEA) regressor results in the specified change (or average change in the case of APE) in the probability.
#
# * Marginal effects show the change in probability when the predictor, or independent, variable increases by one unit. For continuous variables this represents the instantaneous change given that the ‘unit’ may be very small. For binary variables, the change is from 0 to 1, so one ‘unit’ as it is usually thought.
#
#
# * APE uses a vector with the mean of each X, or, the partial effect of for an "average" observation in our sample. An average observation may be very unrealistic, with binary explanatory variables.

# %% [markdown]
# ### Goodness of fit measures
#
# #### Confusion Matrix

# %%
table5 <- table(true = Finaltable$IPR_P, pred = round(fitted(Probit)))
table5
# Out:
#     pred
# true   0   1
#    0 136   5
#    1   9  25

# %%
prop.table(table5)
# Out:
#     pred
# true          0          1
#    0 0.77714286 0.02857143
#    1 0.05142857 0.14285714

# %% [markdown]
# aprox 92% correctly classified and 8% misclassified

# %%
predicted.data <- data.frame(
  probability.of.hd=Probit$fitted.values,
  ipr=Finaltable$IPR_P)

# %%
predicted <- predict(Probit, Finaltable, type="response")

# %%
g6 <- ggplot(predicted.data, aes(ipr))
g6 + geom_bar() + labs(title= "Predicted",  y="Count", x = "Response")
# Out:
# plot without title

# %% [markdown]
# ### Receiver Operating Characteristics (ROC) Curve
# percentage of true positives accurately predicted as the prediction probability cutoff is lowered from 1 to 0. ROC summarizes the model’s performance by evaluating the trade-offs between true positive rate (sensitivity) and false positive rate (1- specificity).

# %%
library(InformationValue)
InformationValue::plotROC(Finaltable$IPR_P, predicted , Show.labels = TRUE)
# Out:
# Warning message:
# “Removed 20 rows containing missing values (geom_text).”
# plot without title

# %%
coeftest(Probit, vcov. = vcovHC, type = "HC1")
# Out:
# z test of coefficients:
#
#                                                                                            Estimate
# (Intercept)                                                                             -3.8874e+00
# Finaltable$QREN_Investimento_Elegivel_Total                                              2.0672e-06
# Finaltable$N_Investors_FINOVA                                                            3.9472e-01
# Finaltable$in_degree_centrality                                                          2.3575e+02
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -2.9628e+00
# Finaltable$NACEF - Construction                                                          6.3123e+00
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -1.8542e-01
# Finaltable$NACEJ - Information and communication                                        -4.6158e-01
# Finaltable$NACEK - Financial and insurance activities                                   -3.4970e+00
# Finaltable$NACEL - Real estate activities                                               -2.9628e+00
# Finaltable$NACEM - Professional, scientific and technical activities                    -1.9068e-01
# Finaltable$NACEN - Administrative and support service activities                         9.5199e-01
# Finaltable$NACER - Arts, entertainment and recreation                                   -2.9628e+00
#                                                                                          Std. Error
# (Intercept)                                                                              6.3143e-01
# Finaltable$QREN_Investimento_Elegivel_Total                                              1.0023e-06
# Finaltable$N_Investors_FINOVA                                                            1.5319e-01
# Finaltable$in_degree_centrality                                                          6.9283e+01
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                   5.2079e-01
# Finaltable$NACEF - Construction                                                          5.1777e-01
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles  1.0874e+00
# Finaltable$NACEJ - Information and communication                                         5.1653e-01
# Finaltable$NACEK - Financial and insurance activities                                    4.5137e-01
# Finaltable$NACEL - Real estate activities                                                5.2079e-01
# Finaltable$NACEM - Professional, scientific and technical activities                     5.2480e-01
# Finaltable$NACEN - Administrative and support service activities                         5.6064e-01
# Finaltable$NACER - Arts, entertainment and recreation                                    5.2079e-01
#                                                                                         z value
# (Intercept)                                                                             -6.1564
# Finaltable$QREN_Investimento_Elegivel_Total                                              2.0623
# Finaltable$N_Investors_FINOVA                                                            2.5767
# Finaltable$in_degree_centrality                                                          3.4026
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  -5.6890
# Finaltable$NACEF - Construction                                                         12.1913
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles -0.1705
# Finaltable$NACEJ - Information and communication                                        -0.8936
# Finaltable$NACEK - Financial and insurance activities                                   -7.7476
# Finaltable$NACEL - Real estate activities                                               -5.6890
# Finaltable$NACEM - Professional, scientific and technical activities                    -0.3633
# Finaltable$NACEN - Administrative and support service activities                         1.6980
# Finaltable$NACER - Arts, entertainment and recreation                                   -5.6890
#                                                                                          Pr(>|z|)
# (Intercept)                                                                             7.440e-10
# Finaltable$QREN_Investimento_Elegivel_Total                                             0.0391754
# Finaltable$N_Investors_FINOVA                                                           0.0099750
# Finaltable$in_degree_centrality                                                         0.0006674
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  1.278e-08
# Finaltable$NACEF - Construction                                                         < 2.2e-16
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles 0.8646096
# Finaltable$NACEJ - Information and communication                                        0.3715308
# Finaltable$NACEK - Financial and insurance activities                                   9.365e-15
# Finaltable$NACEL - Real estate activities                                               1.278e-08
# Finaltable$NACEM - Professional, scientific and technical activities                    0.7163453
# Finaltable$NACEN - Administrative and support service activities                        0.0895003
# Finaltable$NACER - Arts, entertainment and recreation                                   1.278e-08
#
# (Intercept)                                                                             ***
# Finaltable$QREN_Investimento_Elegivel_Total                                             *
# Finaltable$N_Investors_FINOVA                                                           **
# Finaltable$in_degree_centrality                                                         ***
# Finaltable$NACED - Electricity, gas, steam and air conditioning supply                  ***
# Finaltable$NACEF - Construction                                                         ***
# Finaltable$NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles
# Finaltable$NACEJ - Information and communication
# Finaltable$NACEK - Financial and insurance activities                                   ***
# Finaltable$NACEL - Real estate activities                                               ***
# Finaltable$NACEM - Professional, scientific and technical activities
# Finaltable$NACEN - Administrative and support service activities                        .
# Finaltable$NACER - Arts, entertainment and recreation                                   ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Heteroskedasticity-robust standard errors of the coefficient estimators

# %%
rob_se <- (sqrt(diag(vcovHC(Probit, type = "HC1"))))

# %%
stargazer(Probit,  
          digits = 3,
          type = "text", 
          header = FALSE,
          se = rob_se,
          no.space = TRUE,
          model.numbers = FALSE)
# Out:
# ========================================================================================================
#                                                                                  Dependent variable:
#                                                                              ---------------------------
#                                                                                         IPR_P
# --------------------------------------------------------------------------------------------------------
# QREN_Investimento_Elegivel_Total                                                       0.00000
#
# N_Investors_FINOVA                                                                      0.395
#
# in_degree_centrality                                                                   235.747
#
# NACED - Electricity, gas, steam and air conditioning supply                            -2.963
#
# NACEF - Construction                                                                    6.312
#
# NACEG - Wholesale and retail trade, repair of motor vehicles and motorcycles           -0.185
#
# NACEJ - Information and communication                                                  -0.462
#
# NACEK - Financial and insurance activities                                             -3.497
#
# NACEL - Real estate activities                                                         -2.963
#
# NACEM - Professional, scientific and technical activities                              -0.191
#
# NACEN - Administrative and support service activities                                   0.952
#
# NACER - Arts, entertainment and recreation                                             -2.963
#
# Constant                                                                              -3.887***
#                                                                                        (0.631)
# --------------------------------------------------------------------------------------------------------
# Observations                                                                             175
# Log Likelihood                                                                         -32.497
# Akaike Inf. Crit.                                                                      90.994
# ========================================================================================================
# Note:                                                                        *p<0.1; **p<0.05; ***p<0.01

# %% [markdown]
# ### Checking for Multicollinearity - VIF
# (values are below 5, then there are no collinearity problems)

# %%
vif <- car::vif(Probit)
print(vif)
# Out:
#                                                 GVIF Df GVIF^(1/(2*Df))
# Finaltable$QREN_Investimento_Elegivel_Total 1.127447  1        1.061813
# Finaltable$N_Investors_FINOVA               1.088388  1        1.043258
# Finaltable$in_degree_centrality             1.179621  1        1.086103
# Finaltable$NACE                             1.167025  9        1.008618

# %%
# McFadden's Pseudo R-squared
pseudoR2 <- 1 - (Probit$deviance) / (Probit$null.deviance) #McFadden
pseudoR2
# Out:
# [1] 0.6228559

# %% [markdown]
# The Pseudo Pseudo R-squared) was 62,2%, implying that the model explained about 68,8% of the deviations in the probability.

# %% [markdown]
# ## Residuals
#
# In the probit model, the inverse standard normal distribution of the probability is modeled as a linear combination of the predictors.
# tensively. Not much has been proposed in the literature for categorical models.

# %%
plot(predict(Probit),residuals(Probit))
abline(h=0,lty=2,col="grey")
lines(lowess(predict(Probit),residuals(Probit)),col="black",lwd=2)
# Out:
# plot without title

# %%
sum(residuals(Probit, type = "deviance")^2) #Sums of squares:
# Out:
# [1] 64.9941

# %%
sum(residuals(Probit, type = "pearson")^2) #standardized residuals
# Out:
# [1] 76.4615

# %% [markdown]
# Correlation Matrix

# %%
correlationmatrix <- cor(corr, method = c("spearman"))
correlationmatrix
# Out:
# Warning message in cor(corr, method = c("spearman")):
# “the standard deviation is zero”
#                                               N.Contribuinte.do.Promotor
# N.Contribuinte.do.Promotor                     1.00000000
# Incorporation_t0                               0.94624705
# Date_of_first_intervention_t1                  0.68523800
# Maximum_Reported_Investment_in_t2             -0.38181006
# Total_FINOVA                                   0.13916876
# N_Investors_FINOVA                             0.28259249
# Total_Increase_in_SC_from_1st_intervention_t1 -0.26760430
# SC_Final_Intervention_in_t2                   -0.38617247
# Total_Increase_SC_Inv                         -0.31770330
# Percentage_of_special_class_shares             0.02660490
# N_Investors_t2                                -0.01927659
# NACE                                           0.01082946
# Company_not_based_in_PT                                NA
# Exit                                                   NA
# Share_Classes                                  0.28827145
# Private_VC_Number                             -0.13799555
# Private_VC_Investment                         -0.28888069
# QREN_Investimento_Elegivel_N_Operações        -0.22441881
# QREN_Investimento_Elegivel_Total              -0.21718509
# QREN_Sector                                   -0.19627847
# QREN_CAE_Rev3                                 -0.19887312
# QREN_Instrumento                                       NA
# QREN_Concelho                                 -0.19909090
# QREN_Regiao                                   -0.21494907
# QREN_Data_de_Aprovacao                        -0.14774113
# INPI_NICE_N                                   -0.22510787
# INPI_modalidade_N                             -0.22510787
# INPI_modalidade_Moda                          -0.20533547
# INPI_NICE_moda                                -0.18303813
# INPI_dt_ini_vigencia                          -0.16064077
# INPI_Patents_ipc                              -0.06404014
# INPI_Patents_ipc_count                        -0.06359270
# INPI.Patents_moda_mode                        -0.06361473
# INPI_Patents_date                             -0.06314385
# INPI_Design_moda                              -0.11855289
# INPI_Design_moda_count                        -0.11855289
# INPI_Design_fase_actual                       -0.11855289
# INPI_Design_date                              -0.11855289
# IPR                                           -0.22433777
# IPR_P                                         -0.21813994
# FINOVA                                         0.35288572
# QREN                                          -0.19906750
# in_degree_centrality                                   NA
# eigenvector_centrality                                 NA
#                                               Incorporation_t0
# N.Contribuinte.do.Promotor                     0.94624705
# Incorporation_t0                               1.00000000
# Date_of_first_intervention_t1                  0.69479225
# Maximum_Reported_Investment_in_t2             -0.40282556
# Total_FINOVA                                   0.13009151
# N_Investors_FINOVA                             0.26504509
# Total_Increase_in_SC_from_1st_intervention_t1 -0.29677270
# SC_Final_Intervention_in_t2                   -0.40652288
# Total_Increase_SC_Inv                         -0.35156450
# Percentage_of_special_class_shares             0.01125635
# N_Investors_t2                                -0.03806124
# NACE                                           0.02285649
# Company_not_based_in_PT                                NA
# Exit                                                   NA
# Share_Classes                                  0.24683254
# Private_VC_Number                             -0.16022694
# Private_VC_Investment                         -0.29559055
# QREN_Investimento_Elegivel_N_Operações        -0.22816772
# QREN_Investimento_Elegivel_Total              -0.22163156
# QREN_Sector                                   -0.20528621
# QREN_CAE_Rev3                                 -0.20340032
# QREN_Instrumento                                       NA
# QREN_Concelho                                 -0.20925350
# QREN_Regiao                                   -0.22612853
# QREN_Data_de_Aprovacao                        -0.16316565
# INPI_NICE_N                                   -0.22749400
# INPI_modalidade_N                             -0.22749400
# INPI_modalidade_Moda                          -0.21520981
# INPI_NICE_moda                                -0.19369594
# INPI_dt_ini_vigencia                          -0.17029974
# INPI_Patents_ipc                              -0.07456649
# INPI_Patents_ipc_count                        -0.07408326
# INPI.Patents_moda_mode                        -0.07417852
# INPI_Patents_date                             -0.07359838
# INPI_Design_moda                              -0.12018183
# INPI_Design_moda_count                        -0.12018183
# INPI_Design_fase_actual                       -0.12018183
# INPI_Design_date                              -0.12018183
# IPR                                           -0.22687930
# IPR_P                                         -0.20189023
# FINOVA                                         0.33118528
# QREN                                          -0.20888909
# in_degree_centrality                                   NA
# eigenvector_centrality                                 NA
#                                               Date_of_first_intervention_t1
# N.Contribuinte.do.Promotor                     0.685237997
# Incorporation_t0                               0.694792250
# Date_of_first_intervention_t1                  1.000000000
# Maximum_Reported_Investment_in_t2             -0.329654336
# Total_FINOVA                                   0.151244539
# N_Investors_FINOVA                             0.210476673
# Total_Increase_in_SC_from_1st_intervention_t1 -0.324308757
# SC_Final_Intervention_in_t2                   -0.353279423
# Total_Increase_SC_Inv                         -0.371391522
# Percentage_of_special_class_shares             0.004317224
# N_Investors_t2                                -0.182084088
# NACE                                          -0.015052414
# Company_not_based_in_PT                                 NA
# Exit                                                    NA
# Share_Classes                                  0.279950565
# Private_VC_Number                             -0.212764452
# Private_VC_Investment                         -0.281910471
# QREN_Investimento_Elegivel_N_Operações        -0.191717507
# QREN_Investimento_Elegivel_Total              -0.197749992
# QREN_Sector                                   -0.161842536
# QREN_CAE_Rev3                                 -0.169072814
# QREN_Instrumento                                        NA
# QREN_Concelho                                 -0.175256292
# QREN_Regiao                                   -0.191791212
# QREN_Data_de_Aprovacao                        -0.120337510
# INPI_NICE_N                                   -0.187765009
# INPI_modalidade_N                             -0.187765009
# INPI_modalidade_Moda                          -0.172190566
# INPI_NICE_moda                                -0.159391744
# INPI_dt_ini_vigencia                          -0.144599060
# INPI_Patents_ipc                              -0.071585250
# INPI_Patents_ipc_count                        -0.071146679
# INPI.Patents_moda_mode                        -0.071588421
# INPI_Patents_date                             -0.070706532
# INPI_Design_moda                              -0.103494413
# INPI_Design_moda_count                        -0.103494413
# INPI_Design_fase_actual                       -0.103494413
# INPI_Design_date                              -0.103494413
# IPR                                           -0.185028938
# IPR_P                                         -0.168609997
# FINOVA                                         0.288850262
# QREN                                          -0.170056827
# in_degree_centrality                                    NA
# eigenvector_centrality                                  NA
#                                               Maximum_Reported_Investment_in_t2
# N.Contribuinte.do.Promotor                    -0.38181006
# Incorporation_t0                              -0.40282556
# Date_of_first_intervention_t1                 -0.32965434
# Maximum_Reported_Investment_in_t2              1.00000000
# Total_FINOVA                                   0.23372836
# N_Investors_FINOVA                            -0.10524272
# Total_Increase_in_SC_from_1st_intervention_t1  0.37430248
# SC_Final_Intervention_in_t2                    0.46477228
# Total_Increase_SC_Inv                          0.44450535
# Percentage_of_special_class_shares             0.05427953
# N_Investors_t2                                 0.12144205
# NACE                                          -0.03942048
# Company_not_based_in_PT                                NA
# Exit                                                   NA
# Share_Classes                                 -0.10628081
# Private_VC_Number                              0.08657601
# Private_VC_Investment                          0.37823743
# QREN_Investimento_Elegivel_N_Operações         0.20479412
# QREN_Investimento_Elegivel_Total               0.20097587
# QREN_Sector                                    0.20240545
# QREN_CAE_Rev3                                  0.20753702
# QREN_Instrumento                                       NA
# QREN_Concelho                                  0.19321998
# QREN_Regiao                                    0.21125781
# QREN_Data_de_Aprovacao                         0.17846917
# INPI_NICE_N                                    0.19160452
# INPI_modalidade_N                              0.19160452
# INPI_modalidade_Moda                           0.18432606
# INPI_NICE_moda                                 0.16635270
# INPI_dt_ini_vigencia                           0.15223503
# INPI_Patents_ipc                               0.10183923
# INPI_Patents_ipc_count                         0.10175569
# INPI.Patents_moda_mode                         0.10109672
# INPI_Patents_date                              0.10166991
# INPI_Design_moda                               0.08404605
# INPI_Design_moda_count                         0.08404605
# INPI_Design_fase_actual                        0.08404605
# INPI_Design_date                               0.08404605
# IPR                                            0.21500413
# IPR_P                                          0.16769608
# FINOVA                                        -0.20915691
# QREN                                           0.20266115
# in_degree_centrality                                   NA
# eigenvector_centrality                                 NA
#                                               Total_FINOVA N_Investors_FINOVA
# N.Contribuinte.do.Promotor                     0.139168758  0.282592493
# Incorporation_t0                               0.130091514  0.265045088
# Date_of_first_intervention_t1                  0.151244539  0.210476673
# Maximum_Reported_Investment_in_t2              0.233728362 -0.105242716
# Total_FINOVA                                   1.000000000  0.784865842
# N_Investors_FINOVA                             0.784865842  1.000000000
# Total_Increase_in_SC_from_1st_intervention_t1  0.032881185 -0.041043990
# SC_Final_Intervention_in_t2                    0.064642758 -0.073653907
# Total_Increase_SC_Inv                          0.166042886  0.037819694
# Percentage_of_special_class_shares             0.124230963  0.175134303
# N_Investors_t2                                 0.124357768  0.342376971
# NACE                                          -0.010356288  0.001132861
# Company_not_based_in_PT                                 NA           NA
# Exit                                                    NA           NA
# Share_Classes                                 -0.005828846  0.115451432
# Private_VC_Number                             -0.505988037 -0.498362776
# Private_VC_Investment                         -0.710379025 -0.726953606
# QREN_Investimento_Elegivel_N_Operações         0.223838438  0.221492505
# QREN_Investimento_Elegivel_Total               0.213260012  0.220615704
# QREN_Sector                                    0.264009352  0.266609420
# QREN_CAE_Rev3                                  0.264545622  0.263541724
# QREN_Instrumento                                        NA           NA
# QREN_Concelho                                  0.261495956  0.274140884
# QREN_Regiao                                    0.238231247  0.247407337
# QREN_Data_de_Aprovacao                         0.281594584  0.300153534
# INPI_NICE_N                                    0.265693386  0.261010746
# INPI_modalidade_N                              0.265693386  0.261010746
# INPI_modalidade_Moda                           0.260186369  0.262446937
# INPI_NICE_moda                                 0.254806388  0.266181005
# INPI_dt_ini_vigencia                           0.281969318  0.287174837
# INPI_Patents_ipc                              -0.068292879 -0.040932239
# INPI_Patents_ipc_count                        -0.067760367 -0.040172921
# INPI.Patents_moda_mode                        -0.067229333 -0.039414459
# INPI_Patents_date                             -0.067226355 -0.039412713
# INPI_Design_moda                              -0.092161771 -0.098949379
# INPI_Design_moda_count                        -0.092161771 -0.098949379
# INPI_Design_fase_actual                       -0.092161771 -0.098949379
# INPI_Design_date                              -0.092161771 -0.098949379
# IPR                                            0.253957472  0.257838444
# IPR_P                                          0.188204944  0.236808288
# FINOVA                                         0.812137625  0.871950619
# QREN                                           0.253758494  0.263129502
# in_degree_centrality                                    NA           NA
# eigenvector_centrality                                  NA           NA
#                                               Total_Increase_in_SC_from_1st_intervention_t1
# N.Contribuinte.do.Promotor                    -0.2676043015
# Incorporation_t0                              -0.2967726963
# Date_of_first_intervention_t1                 -0.3243087569
# Maximum_Reported_Investment_in_t2              0.3743024838
# Total_FINOVA                                   0.0328811852
# N_Investors_FINOVA                            -0.0410439898
# Total_Increase_in_SC_from_1st_intervention_t1  1.0000000000
# SC_Final_Intervention_in_t2                    0.8655454249
# Total_Increase_SC_Inv                          0.8379178755
# Percentage_of_special_class_shares             0.1702771719
# N_Investors_t2                                 0.1228988232
# NACE                                          -0.0358536006
# Company_not_based_in_PT                                  NA
# Exit                                                     NA
# Share_Classes                                 -0.0091391516
# Private_VC_Number                              0.0044215935
# Private_VC_Investment                          0.1709241056
# QREN_Investimento_Elegivel_N_Operações         0.0365574275
# QREN_Investimento_Elegivel_Total               0.0372879418
# QREN_Sector                                    0.0436607221
# QREN_CAE_Rev3                                  0.0509104161
# QREN_Instrumento                                         NA
# QREN_Concelho                                  0.0602990143
# QREN_Regiao                                    0.0450975642
# QREN_Data_de_Aprovacao                         0.0193538803
# INPI_NICE_N                                    0.0109570098
# INPI_modalidade_N                              0.0109570098
# INPI_modalidade_Moda                           0.0026261235
# INPI_NICE_moda                                 0.0001020339
# INPI_dt_ini_vigencia                           0.0026628868
# INPI_Patents_ipc                               0.1726817340
# INPI_Patents_ipc_count                         0.1726786666
# INPI.Patents_moda_mode                         0.1725499488
# INPI_Patents_date                              0.1726717749
# INPI_Design_moda                              -0.0555266657
# INPI_Design_moda_count                        -0.0555266657
# INPI_Design_fase_actual                       -0.0555266657
# INPI_Design_date                              -0.0555266657
# IPR                                            0.0485322645
# IPR_P                                          0.0365961543
# FINOVA                                        -0.0779999576
# QREN                                           0.0364969539
# in_degree_centrality                                     NA
# eigenvector_centrality                                   NA
#                                               SC_Final_Intervention_in_t2
# N.Contribuinte.do.Promotor                    -0.386172466
# Incorporation_t0                              -0.406522883
# Date_of_first_intervention_t1                 -0.353279423
# Maximum_Reported_Investment_in_t2              0.464772283
# Total_FINOVA                                   0.064642758
# N_Investors_FINOVA                            -0.073653907
# Total_Increase_in_SC_from_1st_intervention_t1  0.865545425
# SC_Final_Intervention_in_t2                    1.000000000
# Total_Increase_SC_Inv                          0.845528809
# Percentage_of_special_class_shares             0.167094391
# N_Investors_t2                                 0.119438477
# NACE                                          -0.038584318
# Company_not_based_in_PT                                 NA
# Exit                                                    NA
# Share_Classes                                 -0.087119746
# Private_VC_Number                              0.058764138
# Private_VC_Investment                          0.195552385
# QREN_Investimento_Elegivel_N_Operações         0.070907317
# QREN_Investimento_Elegivel_Total               0.075570542
# QREN_Sector                                    0.057419427
# QREN_CAE_Rev3                                  0.063262721
# QREN_Instrumento                                        NA
# QREN_Concelho                                  0.083822025
# QREN_Regiao                                    0.081982142
# QREN_Data_de_Aprovacao                         0.028847769
# INPI_NICE_N                                    0.052135347
# INPI_modalidade_N                              0.052135347
# INPI_modalidade_Moda                           0.029690686
# INPI_NICE_moda                                 0.018123018
# INPI_dt_ini_vigencia                           0.007946135
# INPI_Patents_ipc                               0.160561015
# INPI_Patents_ipc_count                         0.160572753
# INPI.Patents_moda_mode                         0.160358964
# INPI_Patents_date                              0.160580935
# INPI_Design_moda                              -0.003001620
# INPI_Design_moda_count                        -0.003001620
# INPI_Design_fase_actual                       -0.003001620
# INPI_Design_date                              -0.003001620
# IPR                                            0.088410766
# IPR_P                                          0.101217246
# FINOVA                                        -0.108741088
# QREN                                           0.060491548
# in_degree_centrality                                    NA
# eigenvector_centrality                                  NA
#                                               Total_Increase_SC_Inv
# N.Contribuinte.do.Promotor                    -0.317703301
# Incorporation_t0                              -0.351564504
# Date_of_first_intervention_t1                 -0.371391522
# Maximum_Reported_Investment_in_t2              0.444505345
# Total_FINOVA                                   0.166042886
# N_Investors_FINOVA                             0.037819694
# Total_Increase_in_SC_from_1st_intervention_t1  0.837917875
# SC_Final_Intervention_in_t2                    0.845528809
# Total_Increase_SC_Inv                          1.000000000
# Percentage_of_special_class_shares             0.173464916
# N_Investors_t2                                 0.127856709
# NACE                                          -0.029425318
# Company_not_based_in_PT                                 NA
# Exit                                                    NA
# Share_Classes                                 -0.112796204
# Private_VC_Number                             -0.010820959
# Private_VC_Investment                          0.093926635
# QREN_Investimento_Elegivel_N_Operações         0.051289198
# QREN_Investimento_Elegivel_Total               0.057358135
# QREN_Sector                                    0.052910031
# QREN_CAE_Rev3                                  0.052257944
# QREN_Instrumento                                        NA
# QREN_Concelho                                  0.075164568
# QREN_Regiao                                    0.066299368
# QREN_Data_de_Aprovacao                         0.027154786
# INPI_NICE_N                                    0.031088479
# INPI_modalidade_N                              0.031088479
# INPI_modalidade_Moda                           0.011239311
# INPI_NICE_moda                                 0.009149990
# INPI_dt_ini_vigencia                           0.006052174
# INPI_Patents_ipc                               0.149049391
# INPI_Patents_ipc_count                         0.149265159
# INPI.Patents_moda_mode                         0.149016156
# INPI_Patents_date                              0.149477622
# INPI_Design_moda                              -0.055525080
# INPI_Design_moda_count                        -0.055525080
# INPI_Design_fase_actual                       -0.055525080
# INPI_Design_date                              -0.055525080
# IPR                                            0.070622828
# IPR_P                                          0.059324103
# FINOVA                                         0.011142533
# QREN                                           0.047470207
# in_degree_centrality                                    NA
# eigenvector_centrality                                  NA
#                                               Percentage_of_special_class_shares
# N.Contribuinte.do.Promotor                     0.026604900
# Incorporation_t0                               0.011256349
# Date_of_first_intervention_t1                  0.004317224
# Maximum_Reported_Investment_in_t2              0.054279525
# Total_FINOVA                                   0.124230963
# N_Investors_FINOVA                             0.175134303
# Total_Increase_in_SC_from_1st_intervention_t1  0.170277172
# SC_Final_Intervention_in_t2                    0.167094391
# Total_Increase_SC_Inv                          0.173464916
# Percentage_of_special_class_shares             1.000000000
# N_Investors_t2                                 0.104987633
# NACE                                          -0.102505560
# Company_not_based_in_PT                                 NA
# Exit                                                    NA
# Share_Classes                                  0.091823186
# Private_VC_Number                             -0.136510615
# Private_VC_Investment                         -0.091128192
# QREN_Investimento_Elegivel_N_Operações        -0.064223085
# QREN_Investimento_Elegivel_Total              -0.064108522
# QREN_Sector                                   -0.064507878
# QREN_CAE_Rev3                                 -0.064112649
# QREN_Instrumento                                        NA
# QREN_Concelho                                 -0.064124092
# QREN_Regiao                                   -0.064216033
# QREN_Data_de_Aprovacao                        -0.064109465
# INPI_NICE_N                                   -0.062413417
# INPI_modalidade_N                             -0.062413417
# INPI_modalidade_Moda                          -0.063140383
# INPI_NICE_moda                                -0.062346820
# INPI_dt_ini_vigencia                          -0.062342206
# INPI_Patents_ipc                              -0.014199371
# INPI_Patents_ipc_count                        -0.014199528
# INPI.Patents_moda_mode                        -0.014200000
# INPI_Patents_date                             -0.014199371
# INPI_Design_moda                              -0.008151121
# INPI_Design_moda_count                        -0.008151121
# INPI_Design_fase_actual                       -0.008151121
# INPI_Design_date                              -0.008151121
# IPR                                           -0.064188379
# IPR_P                                         -0.052798532
# FINOVA                                         0.071828391
# QREN                                          -0.065153221
# in_degree_centrality                                    NA
# eigenvector_centrality                                  NA
#                                               ⋯ INPI_Design_moda
# N.Contribuinte.do.Promotor                    ⋯ -0.118552886
# Incorporation_t0                              ⋯ -0.120181828
# Date_of_first_intervention_t1                 ⋯ -0.103494413
# Maximum_Reported_Investment_in_t2             ⋯  0.084046052
# Total_FINOVA                                  ⋯ -0.092161771
# N_Investors_FINOVA                            ⋯ -0.098949379
# Total_Increase_in_SC_from_1st_intervention_t1 ⋯ -0.055526666
# SC_Final_Intervention_in_t2                   ⋯ -0.003001620
# Total_Increase_SC_Inv                         ⋯ -0.055525080
# Percentage_of_special_class_shares            ⋯ -0.008151121
# N_Investors_t2                                ⋯ -0.078799565
# NACE                                          ⋯ -0.021682138
# Company_not_based_in_PT                       ⋯           NA
# Exit                                          ⋯           NA
# Share_Classes                                 ⋯ -0.104259766
# Private_VC_Number                             ⋯  0.059710526
# Private_VC_Investment                         ⋯  0.115323979
# QREN_Investimento_Elegivel_N_Operações        ⋯  0.163785578
# QREN_Investimento_Elegivel_Total              ⋯  0.159646507
# QREN_Sector                                   ⋯  0.091933105
# QREN_CAE_Rev3                                 ⋯  0.088484483
# QREN_Instrumento                              ⋯           NA
# QREN_Concelho                                 ⋯  0.086576357
# QREN_Regiao                                   ⋯  0.151244188
# QREN_Data_de_Aprovacao                        ⋯  0.087518349
# INPI_NICE_N                                   ⋯  0.125172477
# INPI_modalidade_N                             ⋯  0.125172477
# INPI_modalidade_Moda                          ⋯  0.130587635
# INPI_NICE_moda                                ⋯  0.096709784
# INPI_dt_ini_vigencia                          ⋯  0.085957891
# INPI_Patents_ipc                              ⋯ -0.010011578
# INPI_Patents_ipc_count                        ⋯ -0.010011689
# INPI.Patents_moda_mode                        ⋯ -0.010012022
# INPI_Patents_date                             ⋯ -0.010011578
# INPI_Design_moda                              ⋯  1.000000000
# INPI_Design_moda_count                        ⋯  1.000000000
# INPI_Design_fase_actual                       ⋯  1.000000000
# INPI_Design_date                              ⋯  1.000000000
# IPR                                           ⋯  0.120365492
# IPR_P                                         ⋯  0.154381577
# FINOVA                                        ⋯ -0.113480484
# QREN                                          ⋯  0.125106949
# in_degree_centrality                          ⋯           NA
# eigenvector_centrality                        ⋯           NA
#                                               INPI_Design_moda_count
# N.Contribuinte.do.Promotor                    -0.118552886
# Incorporation_t0                              -0.120181828
# Date_of_first_intervention_t1                 -0.103494413
# Maximum_Reported_Investment_in_t2              0.084046052
# Total_FINOVA                                  -0.092161771
# N_Investors_FINOVA                            -0.098949379
# Total_Increase_in_SC_from_1st_intervention_t1 -0.055526666
# SC_Final_Intervention_in_t2                   -0.003001620
# Total_Increase_SC_Inv                         -0.055525080
# Percentage_of_special_class_shares            -0.008151121
# N_Investors_t2                                -0.078799565
# NACE                                          -0.021682138
# Company_not_based_in_PT                                 NA
# Exit                                                    NA
# Share_Classes                                 -0.104259766
# Private_VC_Number                              0.059710526
# Private_VC_Investment                          0.115323979
# QREN_Investimento_Elegivel_N_Operações         0.163785578
# QREN_Investimento_Elegivel_Total               0.159646507
# QREN_Sector                                    0.091933105
# QREN_CAE_Rev3                                  0.088484483
# QREN_Instrumento                                        NA
# QREN_Concelho                                  0.086576357
# QREN_Regiao                                    0.151244188
# QREN_Data_de_Aprovacao                         0.087518349
# INPI_NICE_N                                    0.125172477
# INPI_modalidade_N                              0.125172477
# INPI_modalidade_Moda                           0.130587635
# INPI_NICE_moda                                 0.096709784
# INPI_dt_ini_vigencia                           0.085957891
# INPI_Patents_ipc                              -0.010011578
# INPI_Patents_ipc_count                        -0.010011689
# INPI.Patents_moda_mode                        -0.010012022
# INPI_Patents_date                             -0.010011578
# INPI_Design_moda                               1.000000000
# INPI_Design_moda_count                         1.000000000
# INPI_Design_fase_actual                        1.000000000
# INPI_Design_date                               1.000000000
# IPR                                            0.120365492
# IPR_P                                          0.154381577
# FINOVA                                        -0.113480484
# QREN                                           0.125106949
# in_degree_centrality                                    NA
# eigenvector_centrality                                  NA
#                                               INPI_Design_fase_actual
# N.Contribuinte.do.Promotor                    -0.118552886
# Incorporation_t0                              -0.120181828
# Date_of_first_intervention_t1                 -0.103494413
# Maximum_Reported_Investment_in_t2              0.084046052
# Total_FINOVA                                  -0.092161771
# N_Investors_FINOVA                            -0.098949379
# Total_Increase_in_SC_from_1st_intervention_t1 -0.055526666
# SC_Final_Intervention_in_t2                   -0.003001620
# Total_Increase_SC_Inv                         -0.055525080
# Percentage_of_special_class_shares            -0.008151121
# N_Investors_t2                                -0.078799565
# NACE                                          -0.021682138
# Company_not_based_in_PT                                 NA
# Exit                                                    NA
# Share_Classes                                 -0.104259766
# Private_VC_Number                              0.059710526
# Private_VC_Investment                          0.115323979
# QREN_Investimento_Elegivel_N_Operações         0.163785578
# QREN_Investimento_Elegivel_Total               0.159646507
# QREN_Sector                                    0.091933105
# QREN_CAE_Rev3                                  0.088484483
# QREN_Instrumento                                        NA
# QREN_Concelho                                  0.086576357
# QREN_Regiao                                    0.151244188
# QREN_Data_de_Aprovacao                         0.087518349
# INPI_NICE_N                                    0.125172477
# INPI_modalidade_N                              0.125172477
# INPI_modalidade_Moda                           0.130587635
# INPI_NICE_moda                                 0.096709784
# INPI_dt_ini_vigencia                           0.085957891
# INPI_Patents_ipc                              -0.010011578
# INPI_Patents_ipc_count                        -0.010011689
# INPI.Patents_moda_mode                        -0.010012022
# INPI_Patents_date                             -0.010011578
# INPI_Design_moda                               1.000000000
# INPI_Design_moda_count                         1.000000000
# INPI_Design_fase_actual                        1.000000000
# INPI_Design_date                               1.000000000
# IPR                                            0.120365492
# IPR_P                                          0.154381577
# FINOVA                                        -0.113480484
# QREN                                           0.125106949
# in_degree_centrality                                    NA
# eigenvector_centrality                                  NA
#                                               INPI_Design_date IPR
# N.Contribuinte.do.Promotor                    -0.118552886     -0.22433777
# Incorporation_t0                              -0.120181828     -0.22687930
# Date_of_first_intervention_t1                 -0.103494413     -0.18502894
# Maximum_Reported_Investment_in_t2              0.084046052      0.21500413
# Total_FINOVA                                  -0.092161771      0.25395747
# N_Investors_FINOVA                            -0.098949379      0.25783844
# Total_Increase_in_SC_from_1st_intervention_t1 -0.055526666      0.04853226
# SC_Final_Intervention_in_t2                   -0.003001620      0.08841077
# Total_Increase_SC_Inv                         -0.055525080      0.07062283
# Percentage_of_special_class_shares            -0.008151121     -0.06418838
# N_Investors_t2                                -0.078799565      0.20197533
# NACE                                          -0.021682138     -0.10753288
# Company_not_based_in_PT                                 NA              NA
# Exit                                                    NA              NA
# Share_Classes                                 -0.104259766     -0.03870542
# Private_VC_Number                              0.059710526     -0.04867825
# Private_VC_Investment                          0.115323979     -0.10157504
# QREN_Investimento_Elegivel_N_Operações         0.163785578      0.97353953
# QREN_Investimento_Elegivel_Total               0.159646507      0.97839566
# QREN_Sector                                    0.091933105      0.97364284
# QREN_CAE_Rev3                                  0.088484483      0.96905507
# QREN_Instrumento                                        NA              NA
# QREN_Concelho                                  0.086576357      0.96544455
# QREN_Regiao                                    0.151244188      0.97635362
# QREN_Data_de_Aprovacao                         0.087518349      0.96092977
# INPI_NICE_N                                    0.125172477      0.96722988
# INPI_modalidade_N                              0.125172477      0.96722988
# INPI_modalidade_Moda                           0.130587635      0.95214057
# INPI_NICE_moda                                 0.096709784      0.93482689
# INPI_dt_ini_vigencia                           0.085957891      0.92431148
# INPI_Patents_ipc                              -0.010011578      0.24677995
# INPI_Patents_ipc_count                        -0.010011689      0.24667085
# INPI.Patents_moda_mode                        -0.010012022      0.24659277
# INPI_Patents_date                             -0.010011578      0.24655629
# INPI_Design_moda                               1.000000000      0.12036549
# INPI_Design_moda_count                         1.000000000      0.12036549
# INPI_Design_fase_actual                        1.000000000      0.12036549
# INPI_Design_date                               1.000000000      0.12036549
# IPR                                            0.120365492      1.00000000
# IPR_P                                          0.154381577      0.87945905
# FINOVA                                        -0.113480484      0.11518105
# QREN                                           0.125106949      0.98519119
# in_degree_centrality                                    NA              NA
# eigenvector_centrality                                  NA              NA
#                                               IPR_P         FINOVA
# N.Contribuinte.do.Promotor                    -0.2181399394  0.35288572
# Incorporation_t0                              -0.2018902304  0.33118528
# Date_of_first_intervention_t1                 -0.1686099971  0.28885026
# Maximum_Reported_Investment_in_t2              0.1676960825 -0.20915691
# Total_FINOVA                                   0.1882049437  0.81213762
# N_Investors_FINOVA                             0.2368082882  0.87195062
# Total_Increase_in_SC_from_1st_intervention_t1  0.0365961543 -0.07799996
# SC_Final_Intervention_in_t2                    0.1012172458 -0.10874109
# Total_Increase_SC_Inv                          0.0593241033  0.01114253
# Percentage_of_special_class_shares            -0.0527985321  0.07182839
# N_Investors_t2                                 0.2298864840  0.13820231
# NACE                                          -0.0671627505  0.01991898
# Company_not_based_in_PT                                  NA          NA
# Exit                                                     NA          NA
# Share_Classes                                 -0.0834561591  0.09604575
# Private_VC_Number                              0.0005093578 -0.52617440
# Private_VC_Investment                         -0.0881969378 -0.81460911
# QREN_Investimento_Elegivel_N_Operações         0.7993564883  0.09747730
# QREN_Investimento_Elegivel_Total               0.8201003941  0.09008413
# QREN_Sector                                    0.7944204743  0.13675754
# QREN_CAE_Rev3                                  0.7888202622  0.13309453
# QREN_Instrumento                                         NA          NA
# QREN_Concelho                                  0.7845626611  0.13625787
# QREN_Regiao                                    0.8251462976  0.10862809
# QREN_Data_de_Aprovacao                         0.7821850084  0.16400575
# INPI_NICE_N                                    0.8357641818  0.13229349
# INPI_modalidade_N                              0.8357641818  0.13229349
# INPI_modalidade_Moda                           0.7706742456  0.13512591
# INPI_NICE_moda                                 0.7544745138  0.14442703
# INPI_dt_ini_vigencia                           0.7196194001  0.17533993
# INPI_Patents_ipc                               0.2689349619 -0.10347131
# INPI_Patents_ipc_count                         0.2689379399 -0.10292786
# INPI.Patents_moda_mode                         0.2689468746 -0.10238667
# INPI_Patents_date                              0.2689349619 -0.10238214
# INPI_Design_moda                               0.1543815773 -0.11348048
# INPI_Design_moda_count                         0.1543815773 -0.11348048
# INPI_Design_fase_actual                        0.1543815773 -0.11348048
# INPI_Design_date                               0.1543815773 -0.11348048
# IPR                                            0.8794590481  0.11518105
# IPR_P                                          1.0000000000  0.07790187
# FINOVA                                         0.0779018748  1.00000000
# QREN                                           0.8103748571  0.12568479
# in_degree_centrality                                     NA          NA
# eigenvector_centrality                                   NA          NA
#                                               QREN        in_degree_centrality
# N.Contribuinte.do.Promotor                    -0.19906750 NA
# Incorporation_t0                              -0.20888909 NA
# Date_of_first_intervention_t1                 -0.17005683 NA
# Maximum_Reported_Investment_in_t2              0.20266115 NA
# Total_FINOVA                                   0.25375849 NA
# N_Investors_FINOVA                             0.26312950 NA
# Total_Increase_in_SC_from_1st_intervention_t1  0.03649695 NA
# SC_Final_Intervention_in_t2                    0.06049155 NA
# Total_Increase_SC_Inv                          0.04747021 NA
# Percentage_of_special_class_shares            -0.06515322 NA
# N_Investors_t2                                 0.18951229 NA
# NACE                                          -0.12865005 NA
# Company_not_based_in_PT                                NA NA
# Exit                                                   NA NA
# Share_Classes                                 -0.02430887 NA
# Private_VC_Number                             -0.05319906 NA
# Private_VC_Investment                         -0.09848444 NA
# QREN_Investimento_Elegivel_N_Operações         0.98572387 NA
# QREN_Investimento_Elegivel_Total               0.98396550 NA
# QREN_Sector                                    0.99009499 NA
# QREN_CAE_Rev3                                  0.98402885 NA
# QREN_Instrumento                                       NA NA
# QREN_Concelho                                  0.98420448 NA
# QREN_Regiao                                    0.98561563 NA
# QREN_Data_de_Aprovacao                         0.98397998 NA
# INPI_NICE_N                                    0.95794830 NA
# INPI_modalidade_N                              0.95794830 NA
# INPI_modalidade_Moda                           0.96910608 NA
# INPI_NICE_moda                                 0.95692613 NA
# INPI_dt_ini_vigencia                           0.95685532 NA
# INPI_Patents_ipc                               0.21793813 NA
# INPI_Patents_ipc_count                         0.21794054 NA
# INPI.Patents_moda_mode                         0.21794779 NA
# INPI_Patents_date                              0.21793813 NA
# INPI_Design_moda                               0.12510695 NA
# INPI_Design_moda_count                         0.12510695 NA
# INPI_Design_fase_actual                        0.12510695 NA
# INPI_Design_date                               0.12510695 NA
# IPR                                            0.98519119 NA
# IPR_P                                          0.81037486 NA
# FINOVA                                         0.12568479 NA
# QREN                                           1.00000000 NA
# in_degree_centrality                                   NA  1
# eigenvector_centrality                                 NA NA
#                                               eigenvector_centrality
# N.Contribuinte.do.Promotor                    NA
# Incorporation_t0                              NA
# Date_of_first_intervention_t1                 NA
# Maximum_Reported_Investment_in_t2             NA
# Total_FINOVA                                  NA
# N_Investors_FINOVA                            NA
# Total_Increase_in_SC_from_1st_intervention_t1 NA
# SC_Final_Intervention_in_t2                   NA
# Total_Increase_SC_Inv                         NA
# Percentage_of_special_class_shares            NA
# N_Investors_t2                                NA
# NACE                                          NA
# Company_not_based_in_PT                       NA
# Exit                                          NA
# Share_Classes                                 NA
# Private_VC_Number                             NA
# Private_VC_Investment                         NA
# QREN_Investimento_Elegivel_N_Operações        NA
# QREN_Investimento_Elegivel_Total              NA
# QREN_Sector                                   NA
# QREN_CAE_Rev3                                 NA
# QREN_Instrumento                              NA
# QREN_Concelho                                 NA
# QREN_Regiao                                   NA
# QREN_Data_de_Aprovacao                        NA
# INPI_NICE_N                                   NA
# INPI_modalidade_N                             NA
# INPI_modalidade_Moda                          NA
# INPI_NICE_moda                                NA
# INPI_dt_ini_vigencia                          NA
# INPI_Patents_ipc                              NA
# INPI_Patents_ipc_count                        NA
# INPI.Patents_moda_mode                        NA
# INPI_Patents_date                             NA
# INPI_Design_moda                              NA
# INPI_Design_moda_count                        NA
# INPI_Design_fase_actual                       NA
# INPI_Design_date                              NA
# IPR                                           NA
# IPR_P                                         NA
# FINOVA                                        NA
# QREN                                          NA
# in_degree_centrality                          NA
# eigenvector_centrality                         1

# %%
poisson = glm(Finaltable$IPR ~ Finaltable$`QREN_Investimento_Elegivel_N_Operações` + Finaltable$Total_FINOVA  + Finaltable$in_degree_centrality, Finaltable,family ="poisson")
summary(poisson)
# Out:
# Call:
# glm(formula = Finaltable$IPR ~ Finaltable$QREN_Investimento_Elegivel_N_Operações +
#     Finaltable$Total_FINOVA + Finaltable$in_degree_centrality,
#     family = "poisson", data = Finaltable)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -4.3415  -0.6489  -0.5490  -0.5203   4.1118
#
# Coefficients:
#                                                     Estimate Std. Error z value
# (Intercept)                                       -3.003e+00  3.092e-01  -9.714
# Finaltable$QREN_Investimento_Elegivel_N_Operações  4.785e-01  4.720e-02  10.137
# Finaltable$Total_FINOVA                            4.288e-07  6.506e-08   6.591
# Finaltable$in_degree_centrality                    1.856e+02  2.769e+01   6.704
#                                                   Pr(>|z|)
# (Intercept)                                        < 2e-16 ***
# Finaltable$QREN_Investimento_Elegivel_N_Operações  < 2e-16 ***
# Finaltable$Total_FINOVA                           4.38e-11 ***
# Finaltable$in_degree_centrality                   2.03e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 472.05  on 174  degrees of freedom
# Residual deviance: 197.99  on 171  degrees of freedom
# AIC: 336.65
#
# Number of Fisher Scoring iterations: 6
